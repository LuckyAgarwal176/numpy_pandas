# %% [markdown]
# ## Table of Content
# 1. **[Reshape]
# 2. **[Pivot Table]
# 3. **[Duplicate]
# 4. **[Replace]
# 5. **[Index]
# 6. **[Summary Statistics]
# 7. **[Merge, Join, Concatenate]
# 8. **[Rank]

# %% [markdown]
# **Let us import the required library**

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action= 'ignore')

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Reshape'></a>
# ## 1. Reshape

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Write a program to reshape the given dataframe using the melt function, considering 'Day' as the identifier variable
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Day</th>
# <th>ICICI</th>
# <th>HDFC</th>
# </tr>
# <tr>
# <td>MON</td>
# <td>1129</td>
# <td>191</td>
# </tr>
# <tr>
# <td>TUES</td>
# <td>1132</td>
# <td>192</td>
# </tr>
# <tr>
# <td>WED</td>
# <td>1134</td>
# <td>190</td>
# </tr>
# <tr>
# <td>THU</td>
# <td>1152</td>
# <td>190</td>
# </tr>
# <tr>
# <td>FRI</td>
# <td>1152</td>
# <td>188</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Day':['MON','TUES','WED','THU','FRI'],
                 'ICICI':[1129,1132,1134,1152,1152],
                 'HDFC':[191,192,190,190,188]})
df
# Out:
#     Day  ICICI  HDFC
# 0   MON   1129   191
# 1  TUES   1132   192
# 2   WED   1134   190
# 3   THU   1152   190
# 4   FRI   1152   188

# %%
pd.melt(df,id_vars='Day')
# Out:
#     Day variable  value
# 0   MON    ICICI   1129
# 1  TUES    ICICI   1132
# 2   WED    ICICI   1134
# 3   THU    ICICI   1152
# 4   FRI    ICICI   1152
# 5   MON     HDFC    191
# 6  TUES     HDFC    192
# 7   WED     HDFC    190
# 8   THU     HDFC    190
# 9   FRI     HDFC    188

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Stack the dataframe at institute level
#                     <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
# <img src="que2.png">

# %%
abc = pd.MultiIndex.from_product([['institute_A','institute_B'],['Machine_learning','python']])
marks = [[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]]
marks_data = pd.DataFrame(marks,columns=abc,index=['Student_1','Student_2','Student_3','Student_4'])
marks_data
# Out:
#                institute_A             institute_B
#           Machine_learning python Machine_learning python
# Student_1               12     45               67     56
# Student_2               78     89               45     67
# Student_3               45     67               89     90
# Student_4               67     44               56     55

# %%
marks_data.stack(level=0)
# Out:
#                        Machine_learning  python
# Student_1 institute_A                12      45
#           institute_B                67      56
# Student_2 institute_A                78      89
#           institute_B                45      67
# Student_3 institute_A                45      67
#           institute_B                89      90
# Student_4 institute_A                67      44
#           institute_B                56      55

# %% [markdown]
# <a id='Pivoting'></a>
# ## 2. Pivot Table

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df_store=pd.DataFrame({'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]})
df_store
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
df_store.groupby('Store')['Sales'].mean()
# Out:
# Store
# A    63750
# B    57500
# C    89500
# D    87000
# Name: Sales, dtype: int64

# %%
pd.pivot_table(df_store,index=['Store'],values=['Sales'],aggfunc=np.mean)
# Out:
#        Sales
# Store
# A      63750
# B      57500
# C      89500
# D      87000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Compute the average sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
pd.pivot_table(df_store,index=['Location','Store'],values='Sales',aggfunc=np.average)
# Out:
#                  Sales
# Location  Store
# Delhi     A      87000
# Hyderabad A      50000
#           D      85000
# Mumbai    A      40000
#           C      89500
# Pune      A      78000
#           B      57500
#           D      89000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Compute the minimum sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
pd.pivot_table(df_store,index=['Store','Location'] ,values=['Sales','Location'],aggfunc=np.min)
# Out:
#                  Sales
# Store Location
# A     Delhi      87000
#       Hyderabad  50000
#       Mumbai     40000
#       Pune       78000
# B     Pune       45000
# C     Mumbai     89000
# D     Hyderabad  85000
#       Pune       89000

# %% [markdown]
# # . Write a program to count total sales per store

# %%
pd.pivot_table(df_store,values='Sales',index='Store',aggfunc=np.sum)
# Out:
#         Sales
# Store
# A      255000
# B      115000
# C      179000
# D      174000

# %% [markdown]
# # Write a program to sort the dataframe by 'Sales' in ascending order

# %%
df_store.sort_values('Sales',ascending='True')
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 9     B       Pune  70000
# 7     A       Pune  78000
# 6     D  Hyderabad  85000
# 5     A      Delhi  87000
# 4     D       Pune  89000
# 8     C     Mumbai  89000
# 3     C     Mumbai  90000

# %% [markdown]
# # . Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order simultaneously

# %%
df_store.sort_values(['Store','Sales'],ascending=[True,False])
# Out:
#   Store   Location  Sales
# 5     A      Delhi  87000
# 7     A       Pune  78000
# 2     A  Hyderabad  50000
# 0     A     Mumbai  40000
# 9     B       Pune  70000
# 1     B       Pune  45000
# 3     C     Mumbai  90000
# 8     C     Mumbai  89000
# 4     D       Pune  89000
# 6     D  Hyderabad  85000

# %% [markdown]
# # Write a program to select the rows where the sales are higher than 60000 for Mumbai

# %%
df_store[(df_store['Location']=='Mumbai')&(df_store['Sales']>60000)]
# Out:
#   Store Location  Sales  Rank_sales
# 3     C   Mumbai  90000        10.0
# 8     C   Mumbai  89000         8.5

# %% [markdown]
# # Save a given dataframe to a csv file

# %%
df_store.to_csv('SALESDATA.CSV')

# %% [markdown]
# # rank

# %% [markdown]
# # Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order

# %%
df_store['Rank_sales']=df_store['Sales'].rank(method='average',ascending=True)
df_store
# Out:
#   Store   Location  Sales  Rank_sales
# 0     A     Mumbai  40000         1.0
# 1     B       Pune  45000         2.0
# 2     A  Hyderabad  50000         3.0
# 3     C     Mumbai  90000        10.0
# 4     D       Pune  89000         8.5
# 5     A      Delhi  87000         7.0
# 6     D  Hyderabad  85000         6.0
# 7     A       Pune  78000         5.0
# 8     C     Mumbai  89000         8.5
# 9     B       Pune  70000         4.0

# %% [markdown]
# <a id='Duplicating'></a>
# ## 3. Duplicate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Find duplicate rows in the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
employee_data={'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'City':['Sydeny','Chicago','New York','Chicago','Chicago','Texas','London','Chicago']}
df_employee=pd.DataFrame(employee_data)
df_employee
# Out:
#       Name  Salary      City
# 0     John    3400    Sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    London
# 7  Sachine    3000   Chicago

# %%
df_employee[df_employee.duplicated()]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Select duplicate rows, except the last occurrence
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# type your code here
df_employee.drop_duplicates(inplace=True,keep='first')
df_employee.drop_duplicates()
# Out:
#       Name  Salary      City
# 0     John    3400    Sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 5   Robert    3000     Texas
# 6     Aadi    4000    London
# 7  Sachine    3000   Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8.  Select the duplicated rows based on the column names 'Salary' and 'City'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# type your code here
df_employee[df_employee.duplicated(['Salary','City'])]
# Out:
#       Name  Salary     City
# 7  Sachine    3000  Chicago

# %% [markdown]
# <a id='Replacing'></a>
# ## 4. Replace

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9.  Replace 'football' with 'hockey' in the column tournament
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
# type your code here
df_tournament={'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['football','cricket','football','football','cricket']}
df_tournament=pd.DataFrame(df_tournament)

# %%
df_tournament['Tournament']=df_tournament['Tournament'].replace('football','hockey')

df_tournament
# Out:
#     Days Tournament
# 0    Mon     hockey
# 1   Tues    cricket
# 2    Wed     hockey
# 3  Thurs     hockey
# 4    Fri    cricket

# %% [markdown]
# # In column tournament, replace all the 'football' values with 'cricket' using numpy.where

# %%
df_tournament['Tournament']=np.where(['Tournament']=='football','football','cricket')
df_tournament
# Out:
#     Days Tournament
# 0    Mon    cricket
# 1   Tues    cricket
# 2    Wed    cricket
# 3  Thurs    cricket
# 4    Fri    cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10.  Replace all 0's with male and all 1's with female in the gender column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
df=pd.DataFrame({'Name':('john','robert','johny','mia'),'Num_Children':(0,4,5,3),'Gender':(0,0,0,1)})
df
# Out:
#      Name  Num_Children  Gender
# 0    john             0       0
# 1  robert             4       0
# 2   johny             5       0
# 3     mia             3       1

# %%
df['Gender'] = df['Gender'].map({0:'male',1:'female'})
df
# Out:
#      Name  Num_Children  Gender
# 0    john             0    male
# 1  robert             4    male
# 2   johny             5    male
# 3     mia             3  female

# %%
df['Gender'] = df['Gender'].replace({0:'male',1:'female'})
df
# Out:
#      Name  Num_Children  Gender
# 0    john             0    male
# 1  robert             4    male
# 2   johny             5    male
# 3     mia             3  female

# %% [markdown]
# <a id='Indexing'></a>
# ## 5. Index

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 11.  Set 'Name' and 'City' columns as indices for the below dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>City</th>
# <th>Sales</th>
# <th>Expenses</th>
# </tr>
# <tr>
# <td>John</td>
# <td>New York</td>
# <td>60000</td>
# <td>12000</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>Chicago</td>
# <td>42000</td>
# <td>33000</td>
# </tr>
# <tr>
# <td>Jony</td>
# <td>Texas</td>
# <td>50000</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>California</td>
# <td>24000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Edward</td>
# <td>Sydney</td>
# <td>12000</td>
# <td>28000</td>
# </tr>
# <tr>
# <td>Thomas</td>
# <td>New York</td>
# <td>82000</td>
# <td>19000</td>
# </tr>
# <tr>
# <td>Ethan</td>
# <td>Chicago</td>
# <td>59000</td>
# <td>32000</td>
# </tr>
# <tr>
# <td>Olivia</td>
# <td>Sydeney</td>
# <td>85000</td>
# <td>10000</td>
# </tr>
# <tr>
# <td>Arun</td>
# <td>California</td>
# <td>97000</td>
# <td>49000</td>
# </tr>
# <tr>
# <td>Ankita</td>
# <td>Texas</td>
# <td>35000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Paulo</td>
# <td>Chicago</td>
# <td>47000</td>
# <td>55000</td>
# </tr>
#
# </table>

# %%
data_city = pd.DataFrame({'Name':['John','Robert','Jony','Mia','Edward','Thomas','Ethan','Olivia','Arun','Ankita','Paulo'],
                         'City':['New York','Chicago','Texas','California','Sydney','New York','Chicago','Sydney','California','Texas','Chicago'],
                         'Sales':[60000,42000,50000,24000,12000,82000,59000,85000,97000,35000,47000],
                         'Expenses':[12000,33000,40000,34000,28000,19000,32000,10000,49000,34000,55000]})
data_city.set_index(['Name','City'])
# Out:
#                    Sales  Expenses
# Name   City
# John   New York    60000     12000
# Robert Chicago     42000     33000
# Jony   Texas       50000     40000
# Mia    California  24000     34000
# Edward Sydney      12000     28000
# Thomas New York    82000     19000
# Ethan  Chicago     59000     32000
# Olivia Sydney      85000     10000
# Arun   California  97000     49000
# Ankita Texas       35000     34000
# Paulo  Chicago     47000     55000

# %% [markdown]
# <a id='Summary_Statistics'></a>
# ## 6. Summary Statistics

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12.  Find the descriptive statistics for the sales column of the given dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df_sales=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
                      'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],
                      'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df_sales
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df_sales['Sales'].describe()
# Out:
# count       12.000000
# mean     48166.666667
# std      19385.249000
# min      22000.000000
# 25%      28500.000000
# 50%      56000.000000
# 75%      61750.000000
# max      78000.000000
# Name: Sales, dtype: float64

# %%
df_sales.describe()
# Out:
#               Sales
# count     12.000000
# mean   48166.666667
# std    19385.249000
# min    22000.000000
# 25%    28500.000000
# 50%    56000.000000
# 75%    61750.000000
# max    78000.000000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 13.  Find the median of sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
pd.pivot_table(df_sales,index=['Seasons'],aggfunc=np.median)  # returs a data frame
# Out:
#          Sales
# Seasons
# Fall     56000
# Spring   29000
# Summer   67000
# Winter   27000

# %%
df_sales.groupby('Seasons')['Sales'].median()  # returns result in series
# Out:
# Seasons
# Fall      56000
# Spring    29000
# Summer    67000
# Winter    27000
# Name: Sales, dtype: int64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 14. Find the descriptive statistics for categorical data from the dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# type your code here
df_sales.head(2)
# Out:
#   Month  Sales Seasons
# 0   Jan  22000  Winter
# 1   Feb  27000  Winter

# %%
df_sales[['Month','Seasons']].describe()
# Out:
#        Month Seasons
# count     12      12
# unique    12       4
# top      Jan  Spring
# freq       1       3

# %%
df_sales.describe(include='all')
# Out:
#        Month         Sales Seasons
# count     12     12.000000      12
# unique    12           NaN       4
# top      Nov           NaN  Spring
# freq       1           NaN       3
# mean     NaN  48166.666667     NaN
# std      NaN  19385.249000     NaN
# min      NaN  22000.000000     NaN
# 25%      NaN  28500.000000     NaN
# 50%      NaN  56000.000000     NaN
# 75%      NaN  61750.000000     NaN
# max      NaN  78000.000000     NaN

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 15. Find the kurtosis for each subject
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
# type your code here
d=pd.DataFrame({'name':('Emma','Mia','Sophia','James','John'),'Maths':(56,78,78,67,88),'Science':(89,87,78,89,78),'English':(89,89,76,78,87)})

# %%
d.kurtosis()
# Out:
# Maths     -0.219599
# Science   -3.232332
# English   -2.923881
# dtype: float64

# %% [markdown]
# <a id='merge'></a>
# ## 7. Merge, Join, Concatenate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 16. Merge the given dataframes on the column 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
product_df = pd.DataFrame({
   'ID': [101,102,103,104,105],
   'Brand': ['Apple', 'Canon', 'Samsung', 'Nikon', 'Sony'],
   'Product':['iphone', 'DSLR', 'SmartPhone', 'DSLR', 'SmartTV']})
print('product_df')
print(product_df)
print('\n')
print('\n')
print('product_quantity_df')
product_quantity_df = pd.DataFrame({
     'ID': [101,102,103,104,106],
   'Brand': ['Apple', 'Canon', 'Samsung', 'Nikon', 'Sony'],
   'Quantity_sold':[234,344,345,262,356]})
print(product_quantity_df)
# Out:
# product_df
#     ID    Brand     Product
# 0  101    Apple      iphone
# 1  102    Canon        DSLR
# 2  103  Samsung  SmartPhone
# 3  104    Nikon        DSLR
# 4  105     Sony     SmartTV
#
#
#
#
# product_quantity_df
#     ID    Brand  Quantity_sold
# 0  101    Apple            234
# 1  102    Canon            344
# 2  103  Samsung            345
# 3  104    Nikon            262
# 4  106     Sony            356

# %%
pd.merge(product_df,product_quantity_df,on='Brand')
# Out:
#    ID_x    Brand     Product  ID_y  Quantity_sold
# 0   101    Apple      iphone   101            234
# 1   102    Canon        DSLR   102            344
# 2   103  Samsung  SmartPhone   103            345
# 3   104    Nikon        DSLR   104            262
# 4   105     Sony     SmartTV   106            356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 17. Using the dataframes created in question 16, merge the given dataframes by 'ID' and 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.merge(product_df,product_quantity_df,on=['Brand','ID'])
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone            234
# 1  102    Canon        DSLR            344
# 2  103  Samsung  SmartPhone            345
# 3  104    Nikon        DSLR            262

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 18. Using the dataframes created in question 16, perform left join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.merge(product_df,product_quantity_df,on=['Brand','ID'],how='left')
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone          234.0
# 1  102    Canon        DSLR          344.0
# 2  103  Samsung  SmartPhone          345.0
# 3  104    Nikon        DSLR          262.0
# 4  105     Sony     SmartTV            NaN

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 19. Using the dataframes created in question 16, perform outer join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.merge(product_df,product_quantity_df,on=['Brand','ID'],how='outer')
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone          234.0
# 1  102    Canon        DSLR          344.0
# 2  103  Samsung  SmartPhone          345.0
# 3  104    Nikon        DSLR          262.0
# 4  105     Sony     SmartTV            NaN
# 5  106     Sony         NaN          356.0

# %% [markdown]
# # ?20. Using the dataframes created in question 16, perform inner join to combine values in the columns 'Brand' and 'ID'

# %%
pd.merge(product_df,product_quantity_df,on=['Brand','ID'],how='inner')
# Out:
#     ID    Brand     Product  Quantity_sold
# 0  101    Apple      iphone            234
# 1  102    Canon        DSLR            344
# 2  103  Samsung  SmartPhone            345
# 3  104    Nikon        DSLR            262

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 20. Concatenate rows of the given dataframes and assign the store as its key
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#                            Products in Store_A:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>102</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Nikon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>105</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %% [markdown]
#                           Products in Store_B:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>104</td>
#         <td>Apple</td>
#         <td>iPod</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>107</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>101</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %%
Store_A=pd.DataFrame({'Id':(101,102,103,104,105),'Brand':('Apple','Canon','Samsung','Nikon','Sony'),'Product':('iphone','DSLR',
'SmartPhone','DSLR','smartTV')})
Store_B=pd.DataFrame({'Id':(103,104,104,107,101),'Brand':('Apple','Apple','Samsung','Canon','Sony'),'Product':('iphone','iPod',
'SmartPhone','DSLR','smartTV')})

# %%
# type your code here
pd.concat([Store_A,Store_B],axis=0,keys=['Store_A','Store_B'])
# Out:
#             Id    Brand     Product
# Store_A 0  101    Apple      iphone
#         1  102    Canon        DSLR
#         2  103  Samsung  SmartPhone
#         3  104    Nikon        DSLR
#         4  105     Sony     smartTV
# Store_B 0  103    Apple      iphone
#         1  104    Apple        iPod
#         2  104  Samsung  SmartPhone
#         3  107    Canon        DSLR
#         4  101     Sony     smartTV

# %%
pd.concat([Store_A,Store_B],axis=0,ignore_index=True)
# Out:
#     Id    Brand     Product
# 0  101    Apple      iphone
# 1  102    Canon        DSLR
# 2  103  Samsung  SmartPhone
# 3  104    Nikon        DSLR
# 4  105     Sony     smartTV
# 5  103    Apple      iphone
# 6  104    Apple        iPod
# 7  104  Samsung  SmartPhone
# 8  107    Canon        DSLR
# 9  101     Sony     smartTV

# %%
the parameter ignore_index and keys are toggle operation i.e only one can be used at a time
